# %% [markdown]
# # Statistical Methods in Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lesson you'll get some hands-on experience using some of the key summary statistics methods in Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Understand and use the df.describe() and df.info() summary statistics methods
# * Use built-in Pandas methods for calculating summary statistics (.mean(), .std(), .count(), .sum(), .mean(), .median(), .std(), .var() and .quantile())
# * Apply a function to every element in a Series or DataFrame using s.apply() and df.applymap()
#
#
# ## Getting Started
#
# For this lab, we'll be working with a dataset containing information on various lego datasets.  You will find this dataset in the file `lego_sets.csv`.
#
# In the cell below:
#
# * Import pandas and set the standard alias of `pd`
# * Load in the `lego_sets.csv` dataset using the `read_csv()` function
# * Display the head of the DataFrame to get a feel for what we'll be working with

# %%
# Your code here
import pandas as pd

# %%
df = pd.read_csv('lego_sets.csv')
df
# Out:
#        ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0      6-12     29.9900          2.0        277.0               4.0
# 1      6-12     19.9900          2.0        168.0               4.0
# 2      6-12     12.9900         11.0         74.0               4.3
# 3       12+     99.9900         23.0       1032.0               3.6
# 4       12+     79.9900         14.0        744.0               3.2
# 5       12+     59.9900          7.0        597.0               3.7
# 6       12+     59.9900         37.0        598.0               3.7
# 7       12+     49.9900         24.0        780.0               4.4
# 8       12+     39.9900         23.0        468.0               3.6
# 9       12+     39.9900         11.0        444.0               3.6
# 10      12+     39.9900         14.0        386.0               4.1
# 11      12+     34.9900         53.0        321.0               3.2
# 12      12+     29.9900          7.0        361.0               4.2
# 13     7-12    159.9900         63.0        847.0               3.8
# 14      10+     29.9900         13.0        708.0               4.7
# 15      10+     19.9900          1.0        234.0               3.0
# 16      10+     19.9900          1.0        160.0               5.0
# 17      10+      9.9900          1.0        149.0               2.0
# 18      10+      9.9900          1.0        141.0               2.0
# 19      10+      9.9900          3.0        101.0               4.0
# 20      10+      9.9900          2.0        105.0               3.0
# 21      10+      9.9900          1.0        113.0               5.0
# 22      10+      9.9900          1.0        136.0               NaN
# 23      10+      9.9900          2.0         91.0               3.0
# 24      10+      9.9900          7.0        140.0               3.2
# 25      10+      9.9900          5.0        143.0               4.6
# 26      10+      9.9900          3.0        122.0               2.7
# 27      10+      9.9900          5.0        130.0               4.3
# 28      10+      9.9900          3.0        119.0               4.5
# 29      10+      9.9900          1.0        135.0               1.0
# ...     ...         ...          ...          ...               ...
# 12231  7-14     48.7878          5.0        267.0               3.6
# 12232  7-14     48.7878         12.0        293.0               4.9
# 12233  8-14     42.6878         24.0        305.0               4.5
# 12234  7-14     42.6878         18.0        254.0               4.2
# 12235  7-14     30.4878          2.0        198.0               4.0
# 12236  7-14     30.4878          8.0        204.0               4.1
# 12237  7-14     30.4878         19.0        201.0               4.1
# 12238  6-12     18.2878          7.0        141.0               4.0
# 12239  6-12     18.2878         18.0        124.0               4.5
# 12240    5+      4.8678         13.0          8.0               4.3
# 12241  8-14    103.6878          9.0        643.0               4.4
# 12242   16+    365.9878         88.0       4867.0               4.8
# 12243  9-14    225.6878         52.0       2295.0               4.7
# 12244  9-14    134.1878         15.0       1403.0               4.5
# 12245  9-14    103.6878          9.0        830.0               4.6
# 12246  9-14    103.6878         11.0       1202.0               4.7
# 12247  9-14     97.5878          6.0        914.0               4.8
# 12248  9-14     97.5878         19.0        944.0               3.6
# 12249  9-14     82.9478          8.0        876.0               4.7
# 12250  8-14     73.1878          8.0        747.0               4.3
# 12251  8-14     60.9878          7.0        521.0               4.7
# 12252  8-14     60.9878         29.0        544.0               4.6
# 12253  8-14     48.7878         21.0        494.0               4.6
# 12254  7-14     36.5878         10.0        312.0               3.5
# 12255  8-14     36.5878          8.0        341.0               4.2
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# 0      Catapult into action and take back the eggs fr...  75823.0
# 1      Launch a flying attack and rescue the eggs fro...  75822.0
# 2      Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3      Explore the architecture of the United States ...  21030.0
# 4      Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
# 5      Celebrate Shanghai with this LEGO® Architectur...  21039.0
# 6      Celebrate New York City with this LEGO® Archit...  21028.0
# 7      Recreate Buckingham Palace with LEGO® Architec...  21029.0
# 8      Celebrate London with this LEGO® Architecture ...  21034.0
# 9      Celebrate Chicago with this LEGO® Architecture...  21033.0
# 10       Experience the grandeur of the Arc de Triomphe!  21036.0
# 11     Build your own LEGO® interpretation of the ico...  21019.0
# 12     Celebrate Sydney with this LEGO® Architecture ...  21032.0
# 13                   Bring your LEGO® creations to life!  17101.0
# 14         Build a LEGO® BrickHeadz version of yourself!  41597.0
# 15     Train a raptor with LEGO® BrickHeadz™ Owen and...  41614.0
# 16     Join Mr. Incredible and Frozone for LEGO® Bric...  41613.0
# 17     Growl like a Wookiee with a LEGO® BrickHeadz™ ...  41609.0
# 18     Be a rogue with a LEGO® BrickHeadz™ constructi...  41608.0
# 19     Save the universe with LEGO® BrickHeadz Iron M...  41604.0
# 20     Feel the power of Infinity with LEGO® BrickHea...  41605.0
# 21     Be a legendary outlaw with LEGO® BrickHeadz St...  41606.0
# 22     Master the skills of a green-skinned assassin ...  41607.0
# 23     Join the Resistance with a LEGO® BrickHeadz co...  41485.0
# 24     Say “I love you” with a LEGO® BrickHeadz™ Vale...  40270.0
# 25       Stand tall with LEGO® BrickHeadz Wonder Woman™!  41599.0
# 26     Live life in the fast lane with LEGO® BrickHea...  41598.0
# 27     Summon the dark side with a LEGO® BrickHeadz c...  41603.0
# 28     Feel the Force with a LEGO® BrickHeadz constru...  41602.0
# 29               Dive in with LEGO® BrickHeadz Aquaman™!  41600.0
# ...                                                  ...      ...
# 12231               Party on with Superman™ and friends!  70919.0
# 12232              Join Batman™ in a comical food fight!  70920.0
# 12233  Put the heat on The Penguin™ Arctic Roller wit...  70911.0
# 12234  Battle with Batman™ against The Riddler™ and h...  70903.0
# 12235  Bring down Captain Boomerang™ with Batman’s Ba...  70918.0
# 12236  Help Batman™ to stop Scarecrow™ delivering a s...  70910.0
# 12237  Protect the power plant from Mr. Freeze’s ice ...  70901.0
# 12238  Power into the sky to stop Scarecrow’s fear ga...  70913.0
# 12239             Help Batman™ stop The Joker™ escaping!  70900.0
# 12240  Discover new heroes and villains in LEGO® Mini...  71020.0
# 12241           Launch a space mission from the Batcave!  70923.0
# 12242         Live the life of a ninja in NINJAGO® City!  70620.0
# 12243            Join the ninja aboard Wu’s flying ship!  70618.0
# 12244                 Evade the traps inside the Temple!  70617.0
# 12245  Defend NINJAGO® City from Garmadon Shark Mech ...  70656.0
# 12246   Turn sound into a weapon with Cole’s Quake Mech!  70632.0
# 12247       Take on the shark army with Zane’s Ice Tank!  70616.0
# 12248  Put the heat on the shark army with Kai’s Fire...  70615.0
# 12249      Speed to the rescue with Jay’s Lightning Jet!  70614.0
# 12250      Defend NINJAGO® City against Garma Mecha Man!  70613.0
# 12251       Get all fired up at Garmadon’s Volcano Lair!  70631.0
# 12252  Take on Garmadon with the Green Ninja Mech Dra...  70612.0
# 12253  Smash the shark army out of the water with the...  70611.0
# 12254  Battle against evil Jungle Garmadon on the jun...  70608.0
# 12255  Take on the tentacular Flying Jelly Sub with Jay!  70610.0
# 12256  Protect NINJAGO® City from flying Manta Ray Bo...  70609.0
# 12257         Stop a Piranha Attack with Kai and Misako!  70629.0
# 12258   Stop a crime in the NINJAGO® City street market!  70607.0
# 12259  Achieve Spinjitzu greatness with the Green Ninja!  70628.0
# 12260  Practice your Spinjitzu skills with Kai and Zane!  70606.0
#
#                                           prod_long_desc review_difficulty  \
# 0      Use the staircase catapult to launch Red into ...           Average
# 1      Pilot Pig has taken off from Bird Island with ...              Easy
# 2      Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3      Discover the architectural secrets of the icon...           Average
# 4      Discover the architectural secrets of Frank Ll...       Challenging
# 5      Recreate Shanghai in China's blend of historic...           Average
# 6      Celebrate the architectural diversity of New Y...           Average
# 7      Build a LEGO® brick model of London's official...           Average
# 8      Celebrate the architectural diversity of Londo...           Average
# 9      Recreate Chicago’s blend of historical and mod...           Average
# 10     Capture the architectural elegance of one of t...           Average
# 11     Presenting the LEGO® Architecture interpretati...           Average
# 12     Capture the architectural essence and splendor...              Easy
# 13     Take your LEGO® play to the next level with th...           Average
# 14     Fuel your creativity by making a LEGO® BrickHe...           Average
# 15     These LEGO® BrickHeadz™ 41614 Owen & Blue cons...              Easy
# 16     These LEGO® BrickHeadz™ 41613 Mr. Incredible &...         Very Easy
# 17     This LEGO® BrickHeadz™ 41609 Chewbacca is fun ...         Very Easy
# 18     This LEGO® BrickHeadz™ 41608 Han Solo is fun t...         Very Easy
# 19     This Iron Man MK50 LEGO® BrickHeadz constructi...           Average
# 20     This Thanos LEGO® BrickHeadz construction char...              Easy
# 21     This Star-Lord LEGO® BrickHeadz construction c...              Easy
# 22     This Gamora LEGO® BrickHeadz construction char...               NaN
# 23     This LEGO® BrickHeadz construction character f...              Easy
# 24     Build your way to someone’s heart and say “Bee...              Easy
# 25     This Wonder Woman™ LEGO® BrickHeadz constructi...              Easy
# 26     The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 27     This LEGO® BrickHeadz construction character f...              Easy
# 28     This LEGO® BrickHeadz construction character f...              Easy
# 29     This Aquaman™ LEGO® BrickHeadz construction ch...         Very Easy
# ...                                                  ...               ...
# 12231  Recreate the hilarious scene from THE LEGO® BA...              Easy
# 12232  Help Batman™ fend off Egghead™ and Condiment K...           Average
# 12233  Join Batman’s pursuit of The Penguin in THE LE...              Easy
# 12234  Take on four Super-Villains at once in THE LEG...              Easy
# 12235  Glide over bumps in the Gotham City streets an...               NaN
# 12236  Save Gotham City Energy Facility from a fear g...           Average
# 12237  Help Batman™ defend the Gotham City Energy Fac...              Easy
# 12238  Team up with Batman™ to stop Scarecrow™ spread...              Easy
# 12239  Stage a face-off between The Joker™ and Batman...              Easy
# 12240  Bring exciting new play possibilities to exist...         Very Easy
# 12241  Take off from the Batcave in The Bat-Space Shu...           Average
# 12242  Enjoy endless role-play fun in NINJAGO® City, ...       Challenging
# 12243  Construct Wu’s huge ninja training base, Desti...       Challenging
# 12244  Join a ninja mission to infiltrate THE LEGO® N...           Average
# 12245  Help Lloyd to save Nomis and Nancy from Garmad...           Average
# 12246  Fire ‘soundwaves’ from Cole’s Quake Mech to sa...           Average
# 12247  Help Zane save Patty Keys and Torben from the ...           Average
# 12248  Get set for sizzling battle action with this h...           Average
# 12249  Save Ed and Edna from the shark army’s crab wi...           Average
# 12250  Help Lloyd protect civilian Pat from attack by...           Average
# 12251  Join Zane’s mission to infiltrate evil Garmado...           Average
# 12252  Outwit The Green Ninja’s evil father Garmadon ...           Average
# 12253  Launch into battle against the shark army and ...           Average
# 12254  Team up with Wu and Kai to take on Jungle Garm...              Easy
# 12255  Join ninja Jay in battle against the shark arm...           Average
# 12256  Help Cole save Shen-Li in this cool THE LEGO® ...              Easy
# 12257  Play out an action-packed Piranha Mech pursuit...              Easy
# 12258  Team up with Lloyd Garmadon, Nya and Officer T...              Easy
# 12259  Learn all the skills of Spinjitzu with THE LEG...         Very Easy
# 12260  Join the ninja heroes at the dojo with this ac...              Easy
#
#                                      set_name  star_rating  \
# 0                       Bird Island Egg Heist          4.5
# 1                          Piggy Plane Attack          5.0
# 2                            Piggy Car Escape          4.3
# 3              United States Capitol Building          4.6
# 4               Solomon R. Guggenheim Museum®          4.6
# 5                                    Shanghai          4.9
# 6                               New York City          4.2
# 7                           Buckingham Palace          4.7
# 8                                      London          4.7
# 9                                     Chicago          4.8
# 10                            Arc de Triomphe          4.4
# 11                           The Eiffel Tower          4.6
# 12                                     Sydney          4.6
# 13                     BOOST Creative Toolbox          3.4
# 14                                Go Brick Me          4.8
# 15                                Owen & Blue          5.0
# 16                   Mr. Incredible & Frozone          5.0
# 17                                 Chewbacca™          3.0
# 18                                  Han Solo™          4.0
# 19                              Iron Man MK50          4.7
# 20                                     Thanos          5.0
# 21                                  Star-Lord          5.0
# 22                                     Gamora          5.0
# 23                                       Finn          4.5
# 24                            Valentine's Bee          4.9
# 25                              Wonder Woman™          5.0
# 26                                 The Flash™          4.0
# 27                                  Kylo Ren™          5.0
# 28                                        Rey          5.0
# 29                                   Aquaman™          4.0
# ...                                       ...          ...
# 12231   The Justice League™ Anniversary Party          3.2
# 12232                Egghead™ Mech Food Fight          4.8
# 12233              The Penguin™ Arctic Roller          4.8
# 12234               The Riddler™ Riddle Racer          4.2
# 12235                      The Bat-Dune Buggy          4.5
# 12236             Scarecrow™ Special Delivery          4.4
# 12237                  Mr. Freeze™ Ice Attack          4.6
# 12238             Scarecrow™ Fearful Face-off          4.1
# 12239               The Joker™ Balloon Escape          4.7
# 12240         THE LEGO® BATMAN MOVIE Series 2          4.8
# 12241                   The Bat-Space Shuttle          4.8
# 12242                           NINJAGO® City          4.9
# 12243                        Destiny's Bounty          4.9
# 12244  Temple of The Ultimate Ultimate Weapon          4.8
# 12245           garmadon, Garmadon, GARMADON!          4.9
# 12246                              Quake Mech          4.5
# 12247                                Ice Tank          4.8
# 12248                               Fire Mech          4.2
# 12249                           Lightning Jet          5.0
# 12250                         Garma Mecha Man          4.5
# 12251                 Garmadon's Volcano Lair          4.3
# 12252                 Green Ninja Mech Dragon          4.7
# 12253                           Water Strider          4.5
# 12254                            Master Falls          4.0
# 12255                        Flying Jelly Sub          4.6
# 12256                        Manta Ray Bomber          4.3
# 12257                          Piranha Attack          3.6
# 12258                     NINJAGO® City Chase          4.6
# 12259                Lloyd - Spinjitzu Master          5.0
# 12260                      Spinjitzu Training          4.7
#
#                       theme_name  val_star_rating country
# 0                   Angry Birds™              4.0      US
# 1                   Angry Birds™              4.0      US
# 2                   Angry Birds™              4.1      US
# 3                   Architecture              4.3      US
# 4                   Architecture              4.1      US
# 5                   Architecture              4.4      US
# 6                   Architecture              4.1      US
# 7                   Architecture              4.3      US
# 8                   Architecture              4.1      US
# 9                   Architecture              4.5      US
# 10                  Architecture              3.6      US
# 11                  Architecture              4.4      US
# 12                  Architecture              4.2      US
# 13                         BOOST              3.5      US
# 14                    BrickHeadz              4.8      US
# 15                    BrickHeadz              5.0      US
# 16                    BrickHeadz              5.0      US
# 17                    BrickHeadz              4.0      US
# 18                    BrickHeadz              4.0      US
# 19                    BrickHeadz              4.5      US
# 20                    BrickHeadz              5.0      US
# 21                    BrickHeadz              5.0      US
# 22                    BrickHeadz              NaN      US
# 23                    BrickHeadz              4.0      US
# 24                    BrickHeadz              4.7      US
# 25                    BrickHeadz              5.0      US
# 26                    BrickHeadz              3.0      US
# 27                    BrickHeadz              4.8      US
# 28                    BrickHeadz              4.5      US
# 29                    BrickHeadz              3.0      US
# ...                          ...              ...     ...
# 12231     THE LEGO® BATMAN MOVIE              3.4      PT
# 12232     THE LEGO® BATMAN MOVIE              4.6      PT
# 12233     THE LEGO® BATMAN MOVIE              4.4      PT
# 12234     THE LEGO® BATMAN MOVIE              4.4      PT
# 12235     THE LEGO® BATMAN MOVIE              4.0      PT
# 12236     THE LEGO® BATMAN MOVIE              4.1      PT
# 12237     THE LEGO® BATMAN MOVIE              4.4      PT
# 12238     THE LEGO® BATMAN MOVIE              4.4      PT
# 12239     THE LEGO® BATMAN MOVIE              4.6      PT
# 12240                Minifigures              4.0      PT
# 12241     THE LEGO® BATMAN MOVIE              3.5      PT
# 12242  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12243  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12244  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12245  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12246  THE LEGO® NINJAGO® MOVIE™              4.4      PT
# 12247  THE LEGO® NINJAGO® MOVIE™              4.7      PT
# 12248  THE LEGO® NINJAGO® MOVIE™              4.6      PT
# 12249  THE LEGO® NINJAGO® MOVIE™              4.6      PT
# 12250  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12251  THE LEGO® NINJAGO® MOVIE™              5.0      PT
# 12252  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12253  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12254  THE LEGO® NINJAGO® MOVIE™              3.6      PT
# 12255  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12256  THE LEGO® NINJAGO® MOVIE™              4.2      PT
# 12257  THE LEGO® NINJAGO® MOVIE™              4.1      PT
# 12258  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12259  THE LEGO® NINJAGO® MOVIE™              5.0      PT
# 12260  THE LEGO® NINJAGO® MOVIE™              4.8      PT
#
# [12261 rows x 14 columns]

# %% [markdown]
# ## Getting DataFrame-Level Statistics
#
# We'll begin by getting some overall summary statistics on the dataset.  There are two ways we'll get this information-- `.info()` and `.describe()`.
#
# ### Using `.info()`
#
# The `.info()` method provides us metadata on the DataFrame itself.  This allows to answer questions such as:
#
# * What data type does each column contain?
# * How many rows are in my dataset?
# * How many total non-missing values does each column contain?
# * How much memory does the DataFrame take up?
#
# In the cell below, call our DataFrame's `.info()` method.

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
# ages                 12261 non-null object
# list_price           12261 non-null float64
# num_reviews          10641 non-null float64
# piece_count          12261 non-null float64
# play_star_rating     10486 non-null float64
# prod_desc            11884 non-null object
# prod_id              12261 non-null float64
# prod_long_desc       12261 non-null object
# review_difficulty    10206 non-null object
# set_name             12261 non-null object
# star_rating          10641 non-null float64
# theme_name           12258 non-null object
# val_star_rating      10466 non-null float64
# country              12261 non-null object
# dtypes: float64(7), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Interpreting the Results
#
# Read the output above, and then answer the following questions:
#
# How many total rows are in this DataFrame?  How many columns contain numeric data? How many contain categorical data?  Identify at least 3 columns that contain missing values.
#
# Write your answer below this line:
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Using `.describe()`
#
# Whereas `.info()` provides statistics about the DataFrame itself, `.describe()` returns output containing basic summary statistics about the data contained with the DataFrame.
#
# In the cell below, call the DataFrame's `.describe()` method.

# %%
# Your code here
df[['list_price','num_reviews','piece_count','play_star_rating', 'star_rating','val_star_rating']].describe()
# Out:
#          list_price   num_reviews   piece_count  play_star_rating  \
# count  12261.000000  10641.000000  12261.000000      10486.000000
# mean      65.141998     16.826238    493.405921          4.337641
# std       91.980429     36.368984    825.364580          0.652051
# min        2.272400      1.000000      1.000000          1.000000
# 25%       19.990000      2.000000     97.000000          4.000000
# 50%       36.587800      6.000000    216.000000          4.500000
# 75%       70.192200     13.000000    544.000000          4.800000
# max     1104.870000    367.000000   7541.000000          5.000000
#
#         star_rating  val_star_rating
# count  10641.000000     10466.000000
# mean       4.514134         4.228960
# std        0.518865         0.660282
# min        1.800000         1.000000
# 25%        4.300000         4.000000
# 50%        4.700000         4.300000
# 75%        5.000000         4.700000
# max        5.000000         5.000000

# %% [markdown]
# #### Interpreting the Results
#
# The output contains descriptive statistics corresponding to the columns.  Use these to answer the following questions:
#
# How much is the standard deviation for piece count?  How many pieces are in the largest lego set?  How many in the smallest lego set? What is the median `val_star_rating`?
#
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Getting Summary Statistics
#
# Pandas also allows us to easily compute individual summary statistics using built-in methods.  Next, we'll get some practice using these methods.
#
# In the cell below, compute the median value of the `star_rating` column.

# %%
# Your code here
df['star_rating'].quantile(.5)
# Out:
# 4.7

# %% [markdown]
# Next, get a count of the total number of values in `play_star_rating`.

# %%
# Your code here
df['play_star_rating'].count()
# Out:
# 10486

# %% [markdown]
# Now, compute the standard deviation of the `list_price` column.

# %%
# Your code here
df['list_price'].std()
# Out:
# 91.9804293059243

# %% [markdown]
# If we bought every single lego set in this dataset, how many pieces would we have?
#
# > **Note**: If you truly want to answer this accurately, and are up for the challenge, try and remove duplicate lego-set entries before summing the pieces. That is, many of the lego sets are listed multiple times in the dataset above, depending on the country where it is being sold and other unique parameters. If you're stuck, just practice calculating the total number of pieces in the dataset for now.

# %%
# Your code here
df.groupby('prod_id').first().sum()['piece_count']
# Out:
# 319071.0

# %% [markdown]
# Now, let's try getting the value for the 90% quantile.  Do this in the cell below.

# %%
# Your code here
grouped = df.groupby('prod_id').first()
grouped
lambda group: group['piece_count'] >= 917.5)['piece_count'].sum()
# Out:
#            ages  list_price  num_reviews  piece_count  play_star_rating  \
# prod_id
# 630.0        4+      2.4900        180.0          1.0               4.0
# 2304.0     1½-5     14.9900         15.0          1.0               4.4
# 7280.0     5-12     14.9900         85.0          2.0               4.1
# 7281.0     5-12     14.9900         40.0          2.0               4.1
# 7499.0     5-12     19.9900         89.0         24.0               2.9
# 7895.0     5-12     15.9900         47.0          8.0               4.2
# 8293.0     9-16     29.9900         57.0         10.0               4.6
# 9843.0       8+     26.6000         13.0          1.0               3.8
# 10214.0     16+    239.9900        228.0       4295.0               4.2
# 10220.0     16+    119.9900        337.0       1334.0               4.3
# 10242.0     16+     99.9900        134.0       1077.0               4.4
# 10243.0     16+    159.9900        202.0       2469.0               4.7
# 10246.0     16+    159.9900        177.0       2262.0               4.4
# 10247.0     16+    199.9900         91.0       2464.0               4.9
# 10249.0     12+     83.5924        142.0        898.0               3.9
# 10251.0     16+    169.9900        115.0       2382.0               4.5
# 10252.0     16+     99.9900         66.0       1167.0               4.5
# 10253.0     16+    249.9900         64.0       4163.0               3.7
# 10254.0     12+     99.9900         77.0        734.0               4.3
# 10255.0     16+    279.9900         99.0       4002.0               4.7
# 10256.0     16+    369.9900         43.0       5923.0               3.9
# 10257.0     16+    199.9900         53.0       2670.0               4.2
# 10258.0     16+    139.9900         53.0       1686.0               4.1
# 10259.0     12+     79.9900         51.0        902.0               3.8
# 10260.0     16+    169.9900         62.0       2480.0               4.4
# 10507.0     2-5     44.9900         11.0         52.0               4.9
# 10508.0     2-5    109.9900         22.0        134.0               4.6
# 10572.0    1½-5     29.9900          4.0         65.0               4.8
# 10590.0     2-5     19.9900          3.0         29.0               5.0
# 10592.0     2-5     24.9900          2.0         26.0               5.0
# ...         ...         ...          ...          ...               ...
# 76079.0    6-12     19.9900          9.0        197.0               4.3
# 76080.0    7-14     29.9900         12.0        323.0               4.3
# 76082.0    6-12     19.9900          9.0        185.0               3.9
# 76083.0    7-14     39.9900         23.0        375.0               4.4
# 76084.0    7-14     49.9900          6.0        400.0               4.8
# 76085.0    6-12     19.9900          9.0        197.0               3.9
# 76086.0    7-14     49.9900          6.0        622.0               5.0
# 76087.0    9-14    129.9900         13.0        955.0               4.1
# 76088.0    7-14     59.9900          6.0        492.0               4.7
# 76089.0    5-12      9.9900          NaN         89.0               NaN
# 76090.0    5-12      9.9900          NaN         86.0               NaN
# 76091.0    5-12      9.9900          2.0         79.0               3.5
# 76096.0    6-12     19.9900          1.0        199.0               5.0
# 76097.0    7-14     39.9900          5.0        406.0               5.0
# 76098.0    6-12     29.9900          6.0        271.0               4.5
# 76099.0    6-12     19.9900          6.0        229.0               4.4
# 76100.0    7-14     29.9900          7.0        358.0               4.7
# 76101.0    6-12     14.9900         13.0        124.0               4.2
# 76102.0    6-12     19.9900         10.0        223.0               4.4
# 76103.0    7-14     39.9900          3.0        416.0               3.7
# 76104.0    7-14     29.9900         13.0        375.0               4.7
# 76105.0     14+    119.9900         52.0       1363.0               3.2
# 76107.0    8-14     69.9900         17.0        674.0               4.9
# 76108.0    8-14     99.9900          7.0       1004.0               4.8
# 853516.0     6+     14.9900          NaN         30.0               NaN
# 853638.0     7+     16.9900         19.0         61.0               2.1
# 2000409.0    6+    484.9900          2.0       4900.0               5.0
# 2000414.0    6+     36.9900         10.0        219.0               3.9
# 2000430.0    6+    789.9900          7.0       2631.0               4.7
# 2000431.0    6+    754.9900          8.0       2455.0               3.7
#
#                                                    prod_desc  \
# prod_id
# 630.0                                    Everyone needs one!
# 2304.0                                 Start creations here!
# 7280.0                         Add roads to your LEGO® town!
# 7281.0                          Roads for your LEGO® layout!
# 7499.0                     Get killer curves in your tracks!
# 7895.0     Switch tracks – build a bigger, more exciting ...
# 8293.0     Motorize your LEGO® Technic creations with the...
# 9843.0                               Your robot's "fingers!"
# 10214.0                  Build London's famous Tower Bridge!
# 10220.0    Road trips will never be the same again with t...
# 10242.0    Take this MINI Cooper for a nostalgic drive do...
# 10243.0    Have an unforgettable evening at the amazing P...
# 10246.0    Discover hidden clues and surprises at the Det...
# 10247.0    Experience the wonderful LEGO® Creator Ferris ...
# 10249.0    Enjoy the holiday season with the Winter Toy S...
# 10251.0               Make a safe deposit at the Brick Bank!
# 10252.0               Head for the beach with the VW Beetle!
# 10253.0            Build the world’s best-known clock tower!
# 10254.0       Climb aboard the magical Winter Holiday Train!
# 10255.0    Celebrate ten years of Modular Building with t...
# 10256.0    Discover the architectural wonder of the Taj M...
# 10257.0    Discover the fairground’s star attraction with...
# 10258.0                           All aboard the London Bus!
# 10259.0    Head home for the holidays with the Winter Vil...
# 10260.0         Discover a place where music is on the menu!
# 10507.0    Hop aboard My First Train Set for beginning bu...
# 10508.0    Take the rocks down the track with the Deluxe ...
# 10572.0    Learn to discover, build and count with the Al...
# 10590.0    Head off on your holidays with the LEGO® DUPLO...
# 10592.0    Rush to save the burning building in the LEGO®...
# ...                                                      ...
# 76079.0    Team up with Mantis and Rocket and fight back ...
# 76080.0       Team up to take on Ayesha and save the galaxy!
# 76082.0                  Foil the masked robbers’ bank raid!
# 76083.0     Intercept The Shocker and take down the Vulture!
# 76084.0                      Fight for the future of Asgard!
# 76085.0    Protect the precious Mother Box from the evil ...
# 76086.0    Fight for the Mother Box with Batman’s Knightc...
# 76087.0           Unleash the Batmobile from The Flying Fox!
# 76088.0    Battle for freedom in the arena with Hulk and ...
# 76089.0    Jet into a fun-packed Scarlet Spider vs. Sandm...
# 76090.0    Help Star-Lord grab the stolen mixtape from Ne...
# 76091.0    Match Thor against Loki in an epic Mighty Micr...
# 76096.0    Help Superman™ bust out of the Kryptonite prison!
# 76097.0    Power up for battle against the Lex Luthor™ Mech!
# 76098.0    Pursue Reverse Flash™ and grab the Energy Infu...
# 76099.0    Battle Killmonger for the precious vibranium w...
# 76100.0    Capture Killmonger with Nakia’s awesome Royal ...
# 76101.0        Defend Wakanda from attack with the Avengers!
# 76102.0                         Find Thor’s ultimate weapon!
# 76103.0    Repel Corvus Glaive’s thresher attack on the W...
# 76104.0    Bash the ball-shooting gun turret with the Hul...
# 76105.0           Create and show off the mighty Hulkbuster!
# 76107.0    Battle Thanos for the Infinity Gauntlet with t...
# 76108.0    Stop Cull Obsidian and Ebony Maw stealing the ...
# 853516.0   Grow Jestro's army with these hot-headed Lava ...
# 853638.0         Display THE LEGO® BATMAN MOVIE minifigures!
# 2000409.0                                                NaN
# 2000414.0                                                NaN
# 2000430.0                                                NaN
# 2000431.0                                                NaN
#
#                                               prod_long_desc  \
# prod_id
# 630.0      This tool makes it a snap to pull those small ...
# 2304.0     Even big imaginations need a place to start--a...
# 7280.0     Expand your LEGO® town with this set of straig...
# 7281.0     Add a T-junction and curved roads to your LEGO...
# 7499.0     Add flexible train tracks to your locomotive s...
# 7895.0     Switch tracks to help make your track even lon...
# 8293.0     Bring your LEGO® Technic models to life with t...
# 9843.0     The Touch Sensor reacts to touch and release, ...
# 10214.0    Stretching over the River Thames since 1894, t...
# 10220.0    This authentic camper van is a replica of the ...
# 10242.0    Take the iconic MINI Cooper for a drive! This ...
# 10243.0    It’s very busy in the Parisian Restaurant! As ...
# 10246.0    Discover a world of mystery and adventure with...
# 10247.0    LEGO® Creator Expert model has an iconic elega...
# 10249.0    Welcome to the Winter Toy Shop! The holiday se...
# 10251.0    Make a secure deposit at the highly respected ...
# 10252.0    Celebrate the iconic VW Beetle with this aweso...
# 10253.0    Get up close to Big Ben! The clock was first s...
# 10254.0    Gather the family for some festive LEGO® build...
# 10255.0    Take a trip to the amazing Assembly Square, de...
# 10256.0    Build and discover the Taj Mahal! The huge ivo...
# 10257.0    Experience the majestic Carousel with a wealth...
# 10258.0    Celebrate iconic design with this charming dou...
# 10259.0    Head for home with the festive Winter Village ...
# 10260.0    Drop in at the LEGO® Creator Expert 10260 Down...
# 10507.0    Introduce your child to the world of trains an...
# 10508.0    Take LEGO® DUPLO® train building to the next l...
# 10572.0    The LEGO® DUPLO® All-In-One Box of Fun set has...
# 10590.0    Get ready for take-off at the LEGO® DUPLO® Air...
# 10592.0    Jump onto the LEGO® DUPLO® Fire Truck and save...
# ...                                                      ...
# 76079.0    Stage a forest face-off between Taserface in h...
# 76080.0    Stage a cosmic battle with this action-packed ...
# 76082.0    Help Spider-Man to stop the masked robbers bur...
# 76083.0    Team up with Spider-Man and Iron Man to catch ...
# 76084.0    Fly the Commodore spaceship and team up with T...
# 76085.0    Team up with Aquaman™ and the Atlantean guards...
# 76086.0    Drive and crawl with Batman’s all-terrain vehi...
# 76087.0    Team up with the Justice League against Steppe...
# 76088.0    Role-play an arena duel between Thor and Hulk ...
# 76089.0    Stage a LEGO® Marvel Super Heroes Mighty Micro...
# 76090.0    Join Star-Lord in a LEGO® Marvel Super Heroes ...
# 76091.0    Stage a sibling showdown with this fun LEGO® M...
# 76096.0    Join Krypto™ the Superdog’s bid to release Sup...
# 76097.0    Team up with the Justice League heroes to grab...
# 76098.0    Dash with The Flash™ to catch Reverse Flash™ a...
# 76099.0    Team up with Black Panther and Okoye in a Rhin...
# 76100.0    Help Black Panther and Nakia win the ultimate ...
# 76101.0    Join Captain America and Black Widow’s battle ...
# 76102.0    Join Thor, Rocket and Groot on a thrilling Ave...
# 76103.0    Stage an awesome battle at the Wakandan wall w...
# 76104.0    Overpower Proxima Midnight and the Outrider wi...
# 76105.0    Build and display this superhero toy—a highly ...
# 76107.0    Fly into conflict on an uncharted planet aboar...
# 76108.0    Stage a LEGO® Marvel Super Heroes 76108 Sanctu...
# 853516.0   Join the ranks of Jestro's legion of evil mini...
# 853638.0   Show off up to 20 THE LEGO® BATMAN MOVIE minif...
# 2000409.0  The LEGO® SERIOUS PLAY® program is a radical a...
# 2000414.0  The LEGO® SERIOUS PLAY® program is a radical a...
# 2000430.0  The LEGO® SERIOUS PLAY® program is a radical a...
# 2000431.0  The LEGO® SERIOUS PLAY® program is a radical a...
#
#           review_difficulty  \
# prod_id
# 630.0             Very Easy
# 2304.0                 Easy
# 7280.0            Very Easy
# 7281.0            Very Easy
# 7499.0                 Easy
# 7895.0            Very Easy
# 8293.0                 Easy
# 9843.0            Very Easy
# 10214.0         Challenging
# 10220.0         Challenging
# 10242.0             Average
# 10243.0         Challenging
# 10246.0         Challenging
# 10247.0         Challenging
# 10249.0             Average
# 10251.0         Challenging
# 10252.0             Average
# 10253.0         Challenging
# 10254.0             Average
# 10255.0         Challenging
# 10256.0         Challenging
# 10257.0         Challenging
# 10258.0             Average
# 10259.0             Average
# 10260.0         Challenging
# 10507.0                Easy
# 10508.0             Average
# 10572.0           Very Easy
# 10590.0                Easy
# 10592.0           Very Easy
# ...                     ...
# 76079.0                Easy
# 76080.0             Average
# 76082.0                Easy
# 76083.0             Average
# 76084.0                Easy
# 76085.0                Easy
# 76086.0             Average
# 76087.0             Average
# 76088.0             Average
# 76089.0                 NaN
# 76090.0                 NaN
# 76091.0                Easy
# 76096.0             Average
# 76097.0             Average
# 76098.0                Easy
# 76099.0                Easy
# 76100.0             Average
# 76101.0                Easy
# 76102.0                Easy
# 76103.0             Average
# 76104.0                Easy
# 76105.0             Average
# 76107.0             Average
# 76108.0             Average
# 853516.0                NaN
# 853638.0          Very Easy
# 2000409.0              Easy
# 2000414.0              Easy
# 2000430.0              Easy
# 2000431.0           Average
#
#                                                     set_name  star_rating  \
# prod_id
# 630.0                                        Brick Separator          4.8
# 2304.0                          LEGO® DUPLO® Green Baseplate          4.0
# 7280.0                           Straight & Crossroad Plates          3.5
# 7281.0                       T-Junction & Curved Road Plates          3.9
# 7499.0                          Flexible and Straight Tracks          2.5
# 7895.0                                      Switching Tracks          4.1
# 8293.0                       LEGO® Power Functions Motor Set          4.5
# 9843.0                                          Touch Sensor          3.8
# 10214.0                                         Tower Bridge          4.8
# 10220.0                             Volkswagen T1 Camper Van          4.7
# 10242.0                                          MINI Cooper          4.7
# 10243.0                                  Parisian Restaurant          4.9
# 10246.0                                   Detective’s Office          4.6
# 10247.0                                         Ferris Wheel          4.9
# 10249.0                                      Winter Toy Shop          3.8
# 10251.0                                           Brick Bank          4.7
# 10252.0                                    Volkswagen Beetle          4.9
# 10253.0                                              Big Ben          4.6
# 10254.0                                 Winter Holiday Train          4.3
# 10255.0                                      Assembly Square          4.8
# 10256.0                                            Taj Mahal          4.8
# 10257.0                                             Carousel          4.4
# 10258.0                                           London Bus          4.6
# 10259.0                               Winter Village Station          3.8
# 10260.0                                       Downtown Diner          4.6
# 10507.0                                   My First Train Set          4.7
# 10508.0                                     Deluxe Train Set          4.1
# 10572.0                   LEGO® DUPLO® All-in-One-Box-of-Fun          5.0
# 10590.0                                              Airport          5.0
# 10592.0                                           Fire Truck          5.0
# ...                                                      ...          ...
# 76079.0                                       Ravager Attack          4.4
# 76080.0                                     Ayesha's Revenge          4.8
# 76082.0                                     ATM Heist Battle          3.9
# 76083.0                                   Beware the Vulture          4.6
# 76084.0                       The Ultimate Battle for Asgard          4.3
# 76085.0                                   Battle of Atlantis          4.2
# 76086.0                          Knightcrawler Tunnel Attack          5.0
# 76087.0                 Flying Fox: Batmobile Airlift Attack          3.7
# 76088.0                           Thor vs. Hulk: Arena Clash          4.3
# 76089.0            Mighty Micros: Scarlet Spider vs. Sandman          NaN
# 76090.0                  Mighty Micros: Star-Lord vs. Nebula          NaN
# 76091.0                         Mighty Micros: Thor vs. Loki          3.5
# 76096.0                          Superman™ & Krypto™ Team-Up          5.0
# 76097.0                            Lex Luthor™ Mech Takedown          4.8
# 76098.0                           Speed Force Freeze Pursuit          4.8
# 76099.0                           Rhino Face-Off by the Mine          4.7
# 76100.0                           Royal Talon Fighter Attack          4.7
# 76101.0                             Outrider Dropship Attack          4.8
# 76102.0                                  Thor's Weapon Quest          4.4
# 76103.0                        Corvus Glaive Thresher Attack          4.0
# 76104.0                              The Hulkbuster Smash-Up          4.8
# 76105.0                       The Hulkbuster: Ultron Edition          3.8
# 76107.0                              Thanos: Ultimate Battle          4.7
# 76108.0                           Sanctum Sanctorum Showdown          5.0
# 853516.0      LEGO® NEXO KNIGHTS™ Monsters Army-Building Set          NaN
# 853638.0   THE LEGO® BATMAN MOVIE Batman™ Minifigure Coll...          2.9
# 2000409.0                             Window Exploration Bag          5.0
# 2000414.0                                        Starter Kit          3.9
# 2000430.0                         Identity and Landscape Kit          4.6
# 2000431.0                                    Connections Kit          3.4
#
#                         theme_name  val_star_rating country
# prod_id
# 630.0                      Classic              4.6      US
# 2304.0                      DUPLO®              3.3      US
# 7280.0                        City              2.3      US
# 7281.0                        City              2.8      US
# 7499.0                        City              2.2      US
# 7895.0                        City              3.6      US
# 8293.0             Power Functions              3.9      US
# 9843.0                 MINDSTORMS®              3.5      AU
# 10214.0             Creator Expert              4.6      US
# 10220.0             Creator Expert              4.5      US
# 10242.0             Creator Expert              4.5      US
# 10243.0             Creator Expert              4.7      US
# 10246.0             Creator Expert              4.4      US
# 10247.0             Creator Expert              4.7      US
# 10249.0             Creator Expert              3.7      AU
# 10251.0             Creator Expert              4.2      US
# 10252.0             Creator Expert              4.7      US
# 10253.0             Creator Expert              4.6      US
# 10254.0             Creator Expert              4.1      US
# 10255.0             Creator Expert              4.5      US
# 10256.0             Creator Expert              4.5      US
# 10257.0             Creator Expert              4.2      US
# 10258.0             Creator Expert              4.3      US
# 10259.0             Creator Expert              3.4      US
# 10260.0             Creator Expert              4.3      US
# 10507.0                     DUPLO®              4.4      US
# 10508.0                     DUPLO®              3.7      US
# 10572.0                     DUPLO®              4.0      US
# 10590.0                     DUPLO®              4.7      US
# 10592.0                     DUPLO®              5.0      US
# ...                            ...              ...     ...
# 76079.0        Marvel Super Heroes              4.8      US
# 76080.0        Marvel Super Heroes              4.3      US
# 76082.0        Marvel Super Heroes              4.2      US
# 76083.0        Marvel Super Heroes              3.9      US
# 76084.0        Marvel Super Heroes              4.5      US
# 76085.0    DC Comics™ Super Heroes              3.9      US
# 76086.0    DC Comics™ Super Heroes              4.8      US
# 76087.0    DC Comics™ Super Heroes              3.0      US
# 76088.0        Marvel Super Heroes              4.0      US
# 76089.0        Marvel Super Heroes              NaN      US
# 76090.0        Marvel Super Heroes              NaN      US
# 76091.0        Marvel Super Heroes              3.0      US
# 76096.0    DC Comics™ Super Heroes              5.0      US
# 76097.0    DC Comics™ Super Heroes              4.8      US
# 76098.0    DC Comics™ Super Heroes              4.5      US
# 76099.0        Marvel Super Heroes              5.0      US
# 76100.0        Marvel Super Heroes              4.8      US
# 76101.0        Marvel Super Heroes              4.8      US
# 76102.0        Marvel Super Heroes              4.9      US
# 76103.0        Marvel Super Heroes              3.7      US
# 76104.0        Marvel Super Heroes              4.7      US
# 76105.0        Marvel Super Heroes              4.0      US
# 76107.0        Marvel Super Heroes              4.2      US
# 76108.0        Marvel Super Heroes              4.8      US
# 853516.0             NEXO KNIGHTS™              NaN      US
# 853638.0    THE LEGO® BATMAN MOVIE              2.8      US
# 2000409.0            SERIOUS PLAY®              5.0      US
# 2000414.0            SERIOUS PLAY®              3.3      US
# 2000430.0            SERIOUS PLAY®              3.6      US
# 2000431.0            SERIOUS PLAY®              2.9      US
#
# [744 rows x 13 columns]

# %% [markdown]
# ## Getting Summary Statistics on Categorical Data
#
# For obvious reasons, most of the methods we've used so far only work with numerical data--there's no way to calculate the standard deviation of a column containing string values. However, there are some things that we can discover about columns containing categorical data.
#
# In the cell below, get the `.unique()` values contained within the `review_difficulty` column.

# %%
# Your code here
df['review_difficulty'].unique()
# Out:
# array(['Average', 'Easy', 'Challenging', 'Very Easy', nan,
#        'Very Challenging'], dtype=object)

# %% [markdown]
# Now, let's get the `value_counts` for this column, to see how common each is.

# %%
# Your code here
df['review_difficulty'].value_counts()
# Out:
# Easy                4236
# Average             3765
# Very Easy           1139
# Challenging         1058
# Very Challenging       8
# Name: review_difficulty, dtype: int64

# %% [markdown]
# As you can see, these provide us quick and easy ways to get information on columns containing categorical information.
#
#
# ## Using `.applymap()`
#
# When working with pandas DataFrames, we can quickly compute functions on the data contained by using the `applymap()` function and passing in a lambda function.
#
# For instance, we can use `applymap()` to return a version of the DataFrame where every value has been converted to a string.
#
# In the cell below:
#
# * Call our DataFrame's `.applymap()` function and pass in `lambda x: str(x)`
# * Call our new `string_df` object's `.info()` method to confirm that everything has been cast to a string

# %%
string_df = df.applymap(lambda x: str(x))
string_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
# ages                 12261 non-null object
# list_price           12261 non-null object
# num_reviews          12261 non-null object
# piece_count          12261 non-null object
# play_star_rating     12261 non-null object
# prod_desc            12261 non-null object
# prod_id              12261 non-null object
# prod_long_desc       12261 non-null object
# review_difficulty    12261 non-null object
# set_name             12261 non-null object
# star_rating          12261 non-null object
# theme_name           12261 non-null object
# val_star_rating      12261 non-null object
# country              12261 non-null object
# dtypes: object(14)
# memory usage: 1.3+ MB

# %% [markdown]
# Note that everything--even the `NaN` values, has been cast to a string in the example above.
#
# Note that for pandas Series objects (such as a single column in a DataFrame), we can do the same thing using the `apply()` method.
#
# This is just one example of how we can quickly compute custom functions on our DataFrame--this will become especially useful when we learn how to **_normalize_** our datasets in a later section!
#
# ## Summary
#
# In this lab, we learned how to:
#
# * Understand and use the df.describe() and df.info() summary statistics methods
# * Use built-in Pandas methods for calculating summary statistics (.mean(), .std(), .count(), .sum(), .mean(), .median(), .std(), .var() and .quantile())
# * Apply a function to every element in a Series or DataFrame using s.apply() and df.applymap()
